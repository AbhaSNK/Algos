# %%
import yfinance as yahooFinance

# Here We are getting Facebook financial information
# We need to pass FB as argument for that
GetInformation = yahooFinance.Ticker("360ONE.NS")
 
# Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y,
# 2y, 5y, 10y and ytd.
print(GetInformation.history(period="3M"))
# Out:
#              Open        High         Low       Close  Volume  Dividends  \
# Date
# 2023-03-24  422.0  434.850006  419.950012  429.100006  138825          0
#
#             Stock Splits
# Date
# 2023-03-24             0

# %%
GetInformation = yahooFinance.Ticker("360ONE.NS")
#yahoo_financials = yahooFinance('360ONE.NS')
print(GetInformation.get_prev_close_price(period = '3mo'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 3>()
#       1 GetInformation = yahooFinance.Ticker("360ONE.NS")
#       2 #yahoo_financials = yahooFinance('360ONE.NS')
# ----> 3 print(GetInformation.get_prev_close_price(period = '3mo'))
#
# AttributeError: 'Ticker' object has no attribute 'get_prev_close_price'

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Abha N K\\Downloads\\mylastbraincells.csv")
print(df.to_string())
# Out:
#              Tickers
# 0          360ONE.NS
# 1         3MINDIA.NS
# 2      AARTIPHARM.NS
# 3             ABB.NS
# 4      ABBOTINDIA.NS
# 5             ACC.NS
# 6             ACE.NS
# 7      ADANIGREEN.NS
# 8      ADANIPORTS.NS
# 9   ADANITRANS-BL.NS
# 10          ABFRL.NS
# 11     ADVENZYMES.NS
# 12         AETHER.NS
# 13          AFFLE.NS
# 14         AGSTRA.NS
# 15       AHLUCONT.NS
# 16         AIAENG.NS
# 17     AJANTPHARM.NS

# %%
df.iat[0, 0]
# Out:
# '360ONE.NS'

# %%
df.iat[1,0]
# Out:
# '3MINDIA.NS'

# %%
df.iat[2, 0]
# Out:
# 'AARTIPHARM.NS'

# %%
i = df.iat[0,0]
type(i)
# Out:
# str

# %%
data = yahooFinance.download(df.iat[0, 0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 data = yahooFinance.download(df.iat[0, 0])
#
# File ~\anaconda3\lib\site-packages\yfinance\multi.py:112, in download(tickers, start, end, actions, threads, group_by, auto_adjust, back_adjust, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     105         _download_one_threaded(ticker, period=period, interval=interval,
#     106                                start=start, end=end, prepost=prepost,
#     107                                actions=actions, auto_adjust=auto_adjust,
#     108                                back_adjust=back_adjust,
#     109                                progress=(progress and i > 0), proxy=proxy,
#     110                                rounding=rounding, timeout=timeout)
# ...

# %%
data = yahooFinance.download('360ONE.NS', period = '3mo')
print(data).to_string()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-12-26  431.649994  443.487488  431.649994  438.512512  434.529236   93820
# 2022-12-27  440.712494  445.987488  438.687500  440.875000  436.870270   37708
# 2022-12-28  438.987488  443.087494  435.000000  438.274994  434.293854  110428
# 2022-12-29  438.750000  442.475006  435.937500  439.524994  435.532501   84440
# 2022-12-30  439.212494  447.125000  437.750000  444.125000  440.090729  108684
# ...                ...         ...         ...         ...         ...     ...
# 2023-03-20  425.000000  440.000000  415.000000  417.950012  417.950012  118805
# 2023-03-21  419.000000  423.649994  395.100006  401.450012  401.450012  279207
# 2023-03-22  401.000000  435.000000  398.049988  428.700012  428.700012  402438
# 2023-03-23  427.000000  432.549988  413.200012  429.600006  429.600006  175154
# ...

# %%
data = yahooFinance.download(df.iat[0, 0], period = '3mo')
#print(data).to_string()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-12-26  431.649994  443.487488  431.649994  438.512512  434.529236   93820
# 2022-12-27  440.712494  445.987488  438.687500  440.875000  436.870270   37708
# 2022-12-28  438.987488  443.087494  435.000000  438.274994  434.293854  110428
# 2022-12-29  438.750000  442.475006  435.937500  439.524994  435.532501   84440
# 2022-12-30  439.212494  447.125000  437.750000  444.125000  440.090729  108684
# ...                ...         ...         ...         ...         ...     ...
# 2023-03-20  425.000000  440.000000  415.000000  417.950012  417.950012  118805
# 2023-03-21  419.000000  423.649994  395.100006  401.450012  401.450012  279207
# 2023-03-22  401.000000  435.000000  398.049988  428.700012  428.700012  402438
# 2023-03-23  427.000000  432.549988  413.200012  429.600006  429.600006  175154
# ...

# %%
for i in range(3):
    print(i)
    i = i+1
# Out:
# 0
# 1
# 2

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(18):
    data = yahooFinance.download(df.iat[i, 0], period = '3mo')
    print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-12-26  431.649994  443.487488  431.649994  438.512512  434.529236   93820
# 2022-12-27  440.712494  445.987488  438.687500  440.875000  436.870270   37708
# 2022-12-28  438.987488  443.087494  435.000000  438.274994  434.293854  110428
# 2022-12-29  438.750000  442.475006  435.937500  439.524994  435.532501   84440
# 2022-12-30  439.212494  447.125000  437.750000  444.125000  440.090729  108684
# ...                ...         ...         ...         ...         ...     ...
# 2023-03-20  425.000000  440.000000  415.000000  417.950012  417.950012  118805
# 2023-03-21  419.000000  423.649994  395.100006  401.450012  401.450012  279207
# 2023-03-22  401.000000  435.000000  398.049988  428.700012  428.700012  402438
# 2023-03-23  427.000000  432.549988  413.200012  429.600006  429.600006  175154
# ...

# %%
for i in range(18):
    data = yahooFinance.download(df.iat[i, 0], period = '3mo')
    print(data['Adj Close'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-12-26    434.529236
# 2022-12-27    436.870270
# 2022-12-28    434.293854
# 2022-12-29    435.532501
# 2022-12-30    440.090729
#                  ...
# 2023-03-20    417.950012
# 2023-03-21    401.450012
# 2023-03-22    428.700012
# 2023-03-23    429.600006
# 2023-03-24    429.100006
# Name: Adj Close, Length: 63, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-12-26    22386.800781
# 2022-12-27    22333.050781
# 2022-12-28    22101.000000
# 2022-12-29    22017.300781
# 2022-12-30    21943.099609
#                   ...
# 2023-03-20    22916.400391
# 2023-03-21    22733.000000
# 2023-03-22    22350.750000
# 2023-03-23    21783.349609
# 2023-03-24    22323.050781
# Name: Adj Close, Length: 63, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Date
# 2023-01-30    288.250000
# 2023-01-31    273.850006
# ...

# %%
ticker_list = []
for i in range(18):
    ticker_list.append(df.iat[i, 0])
    
print(ticker_list)
# Out:
# ['360ONE.NS', '3MINDIA.NS', 'AARTIPHARM.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ACC.NS', 'ACE.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANITRANS-BL.NS', 'ABFRL.NS', 'ADVENZYMES.NS', 'AETHER.NS', 'AFFLE.NS', 'AGSTRA.NS', 'AHLUCONT.NS', 'AIAENG.NS', 'AJANTPHARM.NS']

# %%
new_data = yahooFinance.download(tickers = ticker_list, period = "3mo")
print(new_data)
# Out:
# [*********************100%***********************]  18 of 18 completed
#              Adj Close                                                         \
#              360ONE.NS    3MINDIA.NS AARTIPHARM.NS       ABB.NS ABBOTINDIA.NS
# Date
# 2022-12-26  434.529236  22386.800781           NaN  2724.649902  21772.550781
# 2022-12-27  436.870270  22333.050781           NaN  2742.649902  21625.400391
# 2022-12-28  434.293854  22101.000000           NaN  2724.350098  21643.150391
# 2022-12-29  435.532501  22017.300781           NaN  2684.199951  21726.199219
# 2022-12-30  440.090729  21943.099609           NaN  2683.000000  21367.199219
# ...                ...           ...           ...          ...           ...
# 2023-03-20  417.950012  22916.400391    280.299988  3298.850098  21327.300781
# 2023-03-21  401.450012  22733.000000    280.799988  3412.350098  21287.849609
# 2023-03-22  428.700012  22350.750000    287.950012  3309.899902  21491.650391
# ...

# %%
new_data = yahooFinance.download(tickers = ticker_list, period = "3mo")
print(new_data['Adj Close'])
# Out:
# [*********************100%***********************]  18 of 18 completed
#              360ONE.NS    3MINDIA.NS  AARTIPHARM.NS       ABB.NS  \
# Date
# 2022-12-26  434.529236  22386.800781            NaN  2724.649902
# 2022-12-27  436.870270  22333.050781            NaN  2742.649902
# 2022-12-28  434.293854  22101.000000            NaN  2724.350098
# 2022-12-29  435.532501  22017.300781            NaN  2684.199951
# 2022-12-30  440.090729  21943.099609            NaN  2683.000000
# ...                ...           ...            ...          ...
# 2023-03-20  417.950012  22916.400391     280.299988  3298.850098
# 2023-03-21  401.450012  22733.000000     280.799988  3412.350098
# 2023-03-22  428.700012  22350.750000     287.950012  3309.899902
# 2023-03-23  429.600006  21783.349609     295.850006  3360.449951
# 2023-03-24  429.100006  22323.050781     285.149994  3346.699951
#
#             ABBOTINDIA.NS    ABFRL.NS       ACC.NS      ACE.NS  ADANIGREEN.NS  \
# Date
# ...

# %%
type(new_data)
# Out:
# pandas.core.frame.DataFrame

# %%
working_data = pd.DataFrame(new_data['Adj Close'])
working_data
# Out:
#              360ONE.NS    3MINDIA.NS  AARTIPHARM.NS       ABB.NS  \
# Date
# 2022-12-26  434.529236  22386.800781            NaN  2724.649902
# 2022-12-27  436.870270  22333.050781            NaN  2742.649902
# 2022-12-28  434.293854  22101.000000            NaN  2724.350098
# 2022-12-29  435.532501  22017.300781            NaN  2684.199951
# 2022-12-30  440.090729  21943.099609            NaN  2683.000000
# ...                ...           ...            ...          ...
# 2023-03-20  417.950012  22916.400391     280.299988  3298.850098
# 2023-03-21  401.450012  22733.000000     280.799988  3412.350098
# 2023-03-22  428.700012  22350.750000     287.950012  3309.899902
# 2023-03-23  429.600006  21783.349609     295.850006  3360.449951
# 2023-03-24  429.100006  22323.050781     285.149994  3346.699951
#
#             ABBOTINDIA.NS    ABFRL.NS       ACC.NS      ACE.NS  ADANIGREEN.NS  \
# Date
# 2022-12-26   21772.550781  288.700012  2423.649902  287.950012    1876.849976
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
GetInformation = yahooFinance.Ticker("360ONE.NS")
 
# Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y,
# 2y, 5y, 10y and ytd.
print(GetInformation.history(period="3M"))
